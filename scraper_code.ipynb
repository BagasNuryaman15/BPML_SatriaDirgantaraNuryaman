# %% [markdown]
# # **Import Library**

# %%
from google_play_scraper import app, reviews_all, Sort 
import pandas as pd

# %% [markdown]
# # **Scraping Code**

# %%
# Mengambil data aplikasi freefire dari Google Play Store
scraping_views = reviews_all(
    'com.dts.freefireth', # FreeFire Id
    lang = 'id', # Mengambil review dalam bahasa Indonesia
    country = 'id', # Mengambil review dari negara Indonesia
    sort = Sort.NEWEST, # Mengambil review terbaru
    count = 2000, # Mengambil 1000 review
)

# Membatasi jumlah review yang diambil
if len(scraping_views) > 10000:
    scraping_views = scraping_views[:10000]

print(f'Pengumpulan review done bang! Total review: {len(scraping_views)}')
# Out:
# Pengumpulan review done bang! Total review: 10000

# %% [markdown]
# # **Loading Data Hasil Scraping**

# %%
ff_df = pd.DataFrame(scraping_views)

# Menampilkan hasil scraping
display(ff_df.head(), ff_df.tail())
# Out:
#                                reviewId         userName  \
# 0  169fd249-9e14-45b3-9fa5-b004f8792271  Pengguna Google
# 1  a59942c7-c9b3-4ffd-a026-3589cbb5be3c  Pengguna Google
# 2  1648cc00-59f2-4dcf-ac05-b974911f3aba  Pengguna Google
# 3  b3e7444a-f50c-415a-b030-2eff43d394c9  Pengguna Google
# 4  66863758-112b-4c94-b583-47b7306f0a6c  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0      sedih bgt njir, akun aku hilang ud level 40an      2              0
# 1  game bayak buk bintang 1 Update terus buk nya ...      1              1
# ...

# %%
# Menampilkan sekilas informasi tentang ff ini 
ff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              10000 non-null  object
#  1   userName              10000 non-null  object
#  2   userImage             10000 non-null  object
#  3   content               10000 non-null  object
#  4   score                 10000 non-null  int64
#  5   thumbsUpCount         10000 non-null  int64
#  6   reviewCreatedVersion  6508 non-null   object
#  7   at                    10000 non-null  datetime64[ns]
#  8   replyContent          7 non-null      object
#  9   repliedAt             7 non-null      datetime64[ns]
#  10  appVersion            6508 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 859.5+ KB

# %% [markdown]
# # **Save Menjadi File CSV**

# %%
ff_df.to_csv('ff_scraping.csv', index=False)
